# %% [markdown]
# <a href="https://colab.research.google.com/github/HongSeongMo/learning_plus_lecture/blob/main/Copy_of_lecture_21_beautifulsoup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# beatifulSoup 임포트
import datetime
from bs4 import BeautifulSoup
# !pip install urllib3
import urllib.request

now = datetime.datetime.now()
nowDate = now.strftime('%Y년 %m월 %d일 %H시 %M분')
nowDate
# Out:
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (2.0.7)
# '2024년 03월 18일 10시 29분'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# 오늘의 날씨
webpage = urllib.request.urlopen('https://search.naver.com/search.naver?where=nexearch&sm=top_hty&fbm=0&ie=utf8&query=%EB%82%B4%EC%9D%BC+%EC%84%9C%EC%9A%B8+%EB%82%A0%EC%94%A8')
soup = BeautifulSoup(webpage, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
#  <html lang="ko"><head> <meta charset="utf-8"/> <meta content="always" name="referrer"/> <meta content="telephone=no,address=no,email=no" name="format-detection"/> <meta content="내일 서울 날씨 : 네이버 통합검색" property="og:title"> <meta content="https://ssl.pstatic.net/sstatic/search/common/og_v3.png" property="og:image"/> <meta content="'내일 서울 날씨'의 네이버 통합검색 결과입니다." property="og:description"/> <meta content="'내일 서울 날씨'의 네이버 통합검색 결과입니다." lang="ko" name="description"/> <title>내일 서울 날씨 : 네이버 통합검색</title> <link href="https://ssl.pstatic.net/sstatic/search/favicon/favicon_191118_pc.ico" rel="shortcut icon"/> <link href="https://ssl.pstatic.net/sstatic/search/opensearch-description.https.xml" rel="search" title="Naver" type="application/opensearchdescription+xml"><script> if (top.frames.length!=0 || window!=top) window.open(location, "_top"); </script><link href="https://ssl.pstatic.net/sstatic/search/pc/css/search1_240314.css" rel="stylesheet" type="text/css"/> <link href="https://ssl.pstatic.net/sstatic/search/pc/css/search2_240314.css" rel="stylesheet" type="text/css"/> <link href="https://ssl.pstatic.net/sstatic/search/pc/css/sp_autocomplete_231130.css" rel="stylesheet" type="text/css"/><script> naver = window.naver || {}; naver.search = naver.search || {}; naver.search.abt_param = ""; </script><script> naver = window.naver || {}; naver.search = naver.search || {}; naver.search.error = (function () { var errorList = Array() ; return { add : function (s) { errorList.push(s) ; }, clear : function () { delete errorList ; }, get : function (s) { return errorList ; }, getString : function (d) { if (typeof d === 'undefined') d = '|' ; return errorList.join(d) ; } } })(); function nx_add_event_handler (event, func) { $Fn(func).attach(document, event) ; } function bt(id, after) { document.getElementById(id).src = after; } function document_write (s) { document.write(s) ; } </script><script> var nx_au_cookie_domain = ".search.naver.com" ; var g_site = "" ; function nx_defer_eval (id) { var codeElement = document.getElementById(id), code = codeElement.innerHTML; eval(code.replace(/\/\*/, '').replace(/\*\//, '')); } function trim_crlf (q) { var crlf = /[\r|\n]/ ; q = q.replace(crlf, "") ; return q ; } function include_script (type, defer, src, charset) { var script = document.createElement("script") ; script.type = type, script.defer = defer ; script.src = src ; if (charset) script.charset = charset ; else script.charset = 'utf-8' ; document.getElementsByTagName('head')[0].appendChild(script) ; return script ; } function include_style (src, charset) { var h = document.getElementsByTagName("head")[0] ; var l = document.createElement('link') ; l.type = 'text/css' ; l.rel = 'stylesheet' ; if (charset) l.charset = charset ; else l.charset = 'utf-8' ; l.media = 'screen' ; l.href = src ; h.appendChild(l) ; } function rank_val (rank, name, sign, number, ad_onair) { this.rank = rank ; this.name = name ; this.sign = sign ; this.number = number ; this.ad_onair = ad_onair ; } function rr_hotquery_val (titleImg, totalLink, ad_onair) { this.titleImg = titleImg ; this.totalLink = totalLink ; this.ad_onair = ad_onair ; } function rr_append () { for (var i=0; i<rr_list.length; i++) if (rr_list[i].qname==hotqry_Name && rr_list[i].dir==hotqry_Dir) return 0 ; var o = { order:hotqry_Order, contid:hotqry_ContID, qname:hotqry_Name, dir:hotqry_Dir, toprank:hotqry_TopRank, rankdown:hotqry_RankDown, clicklog:hotqry_ClickLog, toprank_idx:toprank_idx, lowrank_idx:lowrank_idx, topranklist:toprank, lowranklist:lowrank_idx>=0?lowrank:null } ; rr_list = rr_list.concat(o) ; return 1 ; } var msg_hidden_idle=null; function msg (id) { if(msg_hidden_idle) clearInterval(msg_hidden_idle); if(id) { var mid=document.getElementById(id); mid.style.display=''; mid.style.visibility='visible'; } } function msg_hidden (id, f) { if(f) hidden(id); else msg_hidden_idle=setInterval("hidden('"+id+"')",100); } function hidden (id) { var mid=document.getElementById(id); mid.style.display='none'; mid.s ...
#     /* 토글 패널 스타일 */
#     .weather_layer_pop[aria-hidden="true"] {
#         display: none;
#     }
#     .weather_layer_pop[aria-hidden="false"] {
#         display: block;
#     }
#
#     /* 그래프 스타일 */
#     .cs_weather_new .weather_graph_box .canvas {
#         position: absolute;
#     }
#
#     .cs_weather_new .weather_graph_box .scroll_box > div {
#         position: relative;
#     }
#
#     /* 상단 오늘/내일/모레/월간 탭 노출 스타일 */
#     .content_wrap [data-kgs-tab-panel].open {
#         display: block;
#     }
#     .content_wrap [data-kgs-tab-panel] {
#         display: none;
#     }
# </style> <section class="sc_new cs_weather_new _cs_weather"> <div class="_tab_flicking" data-kgs-tab=""> <div class="api_subject_bx"> <div class="top_wrap"> <div class="title_area _area_panel"> <h2 class="blind">중구 을지로1가</h2> <h2 class="title">중구 을지로1가</h2> <a class="link_cctv" href="https://weather.naver.com/map/09140104?cctv=true" nocr="" onclick="return goOtherCR(this, 'a=nco_x7t*4.cctv&amp;r=1&amp;i=88157038_00000065035F&amp;u=' + urlencode(this.href));" target="_blank"><span class="text_cctv">CCTV</span></a> </div> <div class="sub_tab_area"> <div class="type_scroll"> <div> <ul class="sub_tab_list" data-kgs-selectable="" role="tablist"> <li class="sub_tab" data-kgs-tab-toggle="" role="tab"> <a href="#" nocr="" onclick="goOtherTCR(this, 'a=nco_x7t*4&amp;r=1&amp;i=88157038_00000065035F');return false;"> <span class="menu">오늘</span> </a> </li> <li aria-selected="true" class="sub_tab" data-kgs-tab-toggle="" role="tab"> <a href="#" nocr="" onclick="goOtherTCR(this, 'a=nco_x7t*4&amp;r=1&amp;i=88157038_00000065035F');return false;"> <span class="tab_bar _tab_bar" style="display:none"></span> <span class="menu">내일</span> </a> </li> <li class="sub_tab" data-kgs-tab-toggle="" role="tab"> <a href="#" nocr="" onclick="goOtherTCR(this, 'a=nco_x7t*4&amp;r=1&amp;i=88157038_00000065035F');return false;"> <span class="menu">모레</span> </a> </li> <li class="sub_tab" data-kgs-tab-toggle="" role="tab"> <a href="#" nocr="" onclick="goOtherTCR(this, 'a=nco_x7t*4&amp;r=1&amp;i=88157038_00000065035F');return false;"> <span class="menu">월간</span> </a> </li> </ul> </div> </div> </div> </div> <div class="content_wrap"> <div data-kgs-tab-panel=""> <div class="content_area"> <div class="inner"> <div class="multi_cp_area"> <h3 class="blind">날씨 제공사 설정</h3> <div class="multi_cp_info"> <span class="thumb_box"><img alt="제공사 로고" class="_logo" src="https://ssl.pstatic.net/sstatic/keypage/outside/scui/weather_new_new/img/logo_kma.png" style="width: 20px; height: 20px"/></span> <span class="text"><strong class="provider _provider">기상청</strong></span> </div> <div class="provider_select _provider_select"> <a aria-expanded="false" class="title_select _select_trigger" href="#" nocr=""> <strong class="title">제공</strong> </a> <div aria-hidden="true" class="filter_area _select_panel"> <div class="filter_option"> <div class="filter_wrap"> <div class="filter_group"> <strong class="blind">제공사</strong> <div class="filter_cont"> <ul class="list_item" data-kgs-selectable="" onchange="tCR('a=nco_x7t*4.slcparrow&amp;r=1&amp;i=88157038_00000065035F');" role="tablist"> <li aria-selected="true" class="item" data-kgs-option="weather" role="tab"><a class="item_link" href="#" onclick='return goOtherCR(this,"a=nco_x7t*4&amp;r=1&amp;i="+urlencode("88157038_00000065035F")+"&amp;u="+urlencode(this.href));'>기상청</a></li> <li class="item" data-kgs-option="accuWeather" role="tab"><a class="item_link" href="#" onclick='return goOtherCR(this,"a=nco_x7t*4&amp;r=1&amp;i="+urlencode("88157038_00000065035F")+"&amp;u="+urlencode(this.href));'>아큐웨더</a></li> <li class="item" data-kgs-option="twcWeather" role="tab"><a class="item_link" href="#" onclick='return goOtherCR(this,"a=nco_x7t*4&amp;r=1&amp;i="+urlencode("88157038_00000065035F")+"&amp;u="+urlencode(this.href));'>웨더채널</a></li> <li class="item" data-kgs-option="weatherNews" role="tab"><a class="item_link" href="#" onclick='return goOtherCR(this,"a=nco_x7t*4&amp;r=1&amp;i="+urlencode("88157038_00000065035F")+"&amp;u="+urlencode(this.href));'>웨더뉴스</a></li> </ul> </div> </div> </div> </div> </div> </div> <a class="btn_comparison" href="https://weather.naver.com/compare/09140104" onclick='return goOtherCR(this,"a=nco_x7t*4&amp;r=1&amp;i="+urlencode("88157038_00000065035F")+"&amp;u="+urlencode(this.href));' role="button"><span class="text_comparison">예보비교</span></a> </div> <div class="weather_info"> <div class="status_wrap"> <h3 class="blind">오늘의 날씨</h3> <div class="_today"> <div class="weather_graphic"> <div class="weather_main"> <i class="wt_ico ...
# <video class="api_mov" height="104" loop="true" muted="" playsinline="" preload="none" webkit-playsinline="" width="184">
# <source src="https://a01-g-naver-vod.akamaized.net/navertv/c/read/v2/VOD_ALPHA/navertv_2024_03_18_65/b4b9b594-e514-11ee-b5f5-a0369ffb3a60.mp4?__gda__=1710791272_f0b96513001b6ecf077f07d3abe3ea88" type="video/mp4"/></video>
# <span class="mod_thumb_mask"><i class="spnew api_ico_play3">동영상</i></span>
# <span aria-label="재생시간 01:42" class="time">01:42</span></a></div><div class="info_area"><div class="api_save_group _keep_wrap"><a aria-pressed="false" class="btn_save _keep_trigger" data-cr-off="a=vdo_lst*G.kep&amp;r=&amp;i=" data-cr-on="a=vdo_lst*G.kep&amp;r=&amp;i=" data-url="http://news.naver.com/main/read.naver?mode=LPOD&amp;mid=tvh&amp;oid=056&amp;aid=0011683432" href="#" role="button"><i class="spnew ico_save">문서 저장하기</i></a><div class="api_ly_save _keep_save_layer"><a class="spnew_af item item_save _keep_save" data-cr-off="a=vdo_lst*G.kepoff&amp;r=&amp;i=" data-cr-on="a=vdo_lst*G.kepon&amp;r=&amp;i=" href="#" role="button">Keep에 저장</a>
# <a class="spnew_af item item_quick" href="https://keep.naver.com/" onclick='return goOtherCR(this,"a=vdo_lst*G.kephome&amp;r=&amp;i=&amp;u="+urlencode(this.href))' target="_blank">Keep 바로가기</a></div></div><a class="info_title" href="http://news.naver.com/main/read.naver?mode=LPOD&amp;mid=tvh&amp;oid=056&amp;aid=0011683432" onclick='return goOtherCR(this,"a=vdo_lst*G.tit&amp;r=1&amp;i=1016616097_88000114_000000000000000011683432&amp;g="+urlencode("1:1:0:1111|88000114_000000000000000011683432:0560011683432|0:0:0:1:1")+"&amp;u="+urlencode(this.href))' target="_blank">[<mark>날씨</mark>] 대전·세종·충남 내일 흐리고 비…오후엔 ‘미세먼지’</a><div class="info_sub"><div class="desc_group"><a class="channel" href="http://news.kbs.co.kr/" onclick='return goOtherCR(this,"a=vdo_lst*G.cha&amp;r=1&amp;i=1016616097_88000114_000000000000000011683432&amp;g="+urlencode("1:1:0:1111|88000114_000000000000000011683432:0560011683432|0:0:0:1:1")+"&amp;u="+urlencode(this.href))' target="_blank">KBS</a></div><div class="desc_group"><a class="origin" href="http://news.naver.com" onclick='return goOtherCR(this,"a=vdo_lst*G.sou&amp;r=1&amp;i=1016616097_88000114_000000000000000011683432&amp;g="+urlencode("1:1:0:1111|88000114_000000000000000011683432:0560011683432|0:0:0:1:1")+"&amp;u="+urlencode(this.href))' target="_blank">네이버 뉴스</a>
# <span class="desc">7분 전</span></div></div></div></div></li><li class="video_item _svp_item _ani_type" data-cr-exposure="vdo_lst*K" data-cr-gdid="1016616097_08138262_000000000000000000650426" data-cr-gparam="2:1:0:1111|08138262_000000000000000000650426:4220000650426|0:0:0:1:2" data-cr-rank="2" data-cr-url="http://news.naver.com/main/read.naver?mode=LPOD&amp;mid=tvh&amp;oid=422&amp;aid=0000650426"><div class="video_bx _aniitem _video_preview" data-video-selector=".api_mov"><div class="thumb_area"><a class="link _svp_trigger" data-api="https://s.search.naver.com/p/video/47/search.naver?where=inkey&amp;vid=08138262_000000000000000000650426:4220000650426" data-cr-area="thu" data-is-visible-close-btn="false" href="http://news.naver.com/main/read.naver?mode=LPOD&amp;mid=tvh&amp;oid=422&amp;aid=0000650426"><img class="thumb api_get api_img" height="104" onerror="naver.common.handleImgError(this)" src="https://search.pstatic.net/common/?src=https%3A%2F%2Fimgnews.pstatic.net%2Fimage%2F422%2F2024%2F03%2F18%2Fcover_cover_MYH20240318020400641_20240318184702517.jpg%3Ftype%3Dw540&amp;type=ac368_208" width="184"/>
# <video class="api_mov" height="104" loop="true" muted="" playsinline="" preload="none" webkit-playsinline="" width="184">
# <source src="https://a01-g-naver-vod.akamaized.net/navertv/c/read/v2/VOD_ALPHA/navertv_2024_03_18_1504/90e32f2d-e50c-11ee-a12a-80615f0bcef6.mp4?__gda__=1710787710_be24a8dda27c0a52d2957c0c25ee7069" type="video/mp4"/></video>
# <span class="mod_thumb_mask"><i class="spnew api_ico_play3">동영상</i></span>
# <span class="api_badge_video"><i class="spnew ico_thumbnail"></i>주요장면 2개</span>
# <span aria-label="재생시간 01:26" class="time">01:26</span>
# </a><a class="close_mask _svp_close" href="#" onclick='return tCR("a=vdo_lst*K.close&amp;r=2&amp;i=1016616097_08138262_000000000000000000650426&amp;g="+urlencode("2:1:0:1111|08138262_000000000000000000650426:4220000650426|0:0:0:1:2")+"")' role="button"><span class="close_txt">닫기<i class="spnew ico_close_s"></i></span></a></div><div class="info_area"><div class="api_save_group _keep_wrap"><a aria-pressed="false" class="btn_save _keep_trigger" data-cr-off="a=vdo_lst*K.kep&amp;r=&amp;i=" data-cr-on="a=vdo_lst*K.kep&amp;r=&amp;i=" data-url="http://news.naver.com/main/read.naver?mode=LPOD&amp;mid=tvh&amp;oid=422&amp;aid=0000650426" href="#" role="button"><i class="spnew ico_save">문서 저장하기</i></a><div class="api_ly_save _keep_save_layer"><a class="spnew_af item item_save _keep_save" data-cr-off="a=vdo_lst*K.kepoff&amp;r=&amp;i=" data-cr-on="a=vdo_lst*K.kepon&amp;r=&amp;i=" href="#" role="button">Keep에 저장</a>
# <a class="spnew_af item item_quick" href="https://keep.naver.com/" onclick='return goOtherCR(this,"a=vdo_lst*K.kephome&amp;r=&amp;i=&amp;u="+urlencode(this.href))' target="_blank">Keep 바로가기</a></div></div><a class="info_title" href="http://news.naver.com/main/read.naver?mode=LPOD&amp;mid=tvh&amp;oid=422&amp;aid=0000650426" onclick='return goOtherCR(this,"a=vdo_lst*K.tit&amp;r=2&amp;i=1016616097_08138262_000000000000000000650426&amp;g="+urlencode("2:1:0:1111|08138262_000000000000000000650426:4220000650426|0:0:0:1:2")+"&amp;u="+urlencode(this.href))' target="_blank">[생활<mark>날씨</mark>] 내일 전국 비·눈, 강원산간 폭설…해안가 강풍</a><div class="info_sub"><div class="desc_group"><a class="channel" href="http://www.yonhapnewstv.co.kr" onclick='return goOtherCR(this,"a=vdo_lst*K.cha&amp;r=2&amp;i=1016616097_08138262_000000000000000000650426&amp;g="+urlencode("2:1:0:1111|08138262_000000000000000000650426:4220000650426|0:0:0:1:2")+"&amp;u="+urlencode(this.href))' target="_blank">연합뉴스TV</a></div><div class="desc_group"><a class="origin" href="http://news.naver.com" onclick='return goOtherCR(this,"a=vdo_lst*K.sou&amp;r=2&amp;i=1016616097_08138262_000000000000000000650426&amp;g="+urlencode("2:1:0:1111|08138262_000000000000000000650426:4220000650426|0:0:0:1:2")+"&amp;u="+urlencode(this.href))' target="_blank">네이버 뉴스</a>
# <span class="desc">1시간 전</span></div></div></div></div><div class="video_scene_bx"><div class="video_scene_wrap type_thumbnail"><div class="video_scene"><a class="title_link _expand" href="#" role="button"><div class="title_thumb"><div class="thumb_box"><img class="thumb" height="23" onerror="naver.common.handleImgError(this)" src="https://search.pstatic.net/common/?src=https%3A%2F%2Fvideo-search-phinf.pstatic.net%2FMjAyNDAzMThfMTcx%2FMDAxNzEwNzU1MzkwNTQ3.NT4sBz4V2PG5T7RowfbF5t9idgKT8DIgXobkjGdh58Ag.ZSeN5UMfRhi7xzZSwURQ1b-rIoN7EoWXvXAhZPJPFYcg.JPEG%2F6C39037780CEC00051EA3CC97BA87C3F2840_0.jpg&amp;type=ac176_100" width="40"/></div></div><div class="title_txt">위 동영상의 주요 장면 2개</div><i class="spnew ico_fold">펼치기</i></a><div class="video_link_wrap"><div class="video_common_player_wrap _svp_target"></div></div><div class="stamp_list_wrap"><div class="api_pcpg_wrap"><div class="api_flicking_wrap _scene_conveyer_root" data-fit-type="exact"><div class="flick_bx"><a class="stamp_item _svp_trigger _scene" data-api="https://s.search.naver.com/p/video/47/search.naver?where=inkey&amp;vid=08138262_000000000000000000650426:4220000650426" data-cr-area="chapter" data-cr-gparam="2:1:0:1111|08138262_000000000000000000650426:4220000650426:27|0:0:0:1:2" data-is-visible-close-btn="false" data-seek-time="27" href=""><div class="stamp_thumb_area"><img class="thumb" height="52" onerror="naver.common.handleImgError(this)" src="https://search.pstatic.net/common/?src=https%3A%2F%2Fvideo-search-phinf.pstatic.net%2FMjAyNDAzMThfMTcx%2FMDAxNzEwNzU1MzkwNTQ3.NT4sBz4V2PG5T7RowfbF5t9idgKT8DIgXobkjGdh58Ag.ZSeN5UMfRhi7xzZSwURQ1b-rIoN7EoWXvXAhZPJPFYcg.JPEG%2F6C39037780CEC00051EA3CC97BA87C3F2840_0.jpg&amp;type=ac176_100" width="91"/></div><div class="stamp_info_area"><div class="stamp_time">00:27</div><div class="dsc">폭설</div></div></a></div><div class="flick_bx"><a class="stamp_item _svp_trigger _scene" data-api="https://s.search.naver.com/p/video/47/search.naver?where=inkey&amp;vid=08138262_000000000000000000650426:4220000650426" data-cr-area="chapter" data-cr-gparam="2:1:0:1111|08138262_000000000000000000650426:4220000650426:61|0:0:0:1:2" data-is-visible-close-btn="false" data-seek-time="61" href=""><div class="stamp_thumb_area"><img class="thumb" height="52" onerror="naver.common.handleImgError(this)" src="https://search.pstatic.net/common/?src=https%3A%2F%2Fvideo-search-phinf.pstatic.net%2FMjAyNDAzMThfMTM5%2FMDAxNzEwNzU1MzkwODQ4.BmoFZl7isXRHfzhV8mVNghxsj5JzxnSPEOakOxd05wQg.K2k2aL7NSZKjEGvQcZsC7lVlcWzbiLNfmb4OY5QMKpMg.JPEG%2F6C39037780CEC00051EA3CC97BA87C3F2840_0.jpg&amp;type=ac176_100" width="91"/></div><div class="stamp_info_area"><div class="stamp_time">01:01</div><div class="dsc">내일</div></div></a></div></div><div class="api_btn_page"><div class="btn_prev _prev" style="display: none;"><a class="btn" href="#" onclick='return tCR("a=vdo_lst.leftbt&amp;r=0&amp;i=&amp;g=")' role="button"><i class="spnew ico_arr">이전</i></a></div><div class="btn_next _next"><a class="btn" href="#" onclick='return tCR("a=vdo_lst.rightbt&amp;r=0&amp;i=&amp;g=")' role="button"><i class="spnew ico_arr">다음</i></a></div></div></div></div></div></div><div class="mod_ly_notice">영상 내 주요 장면을 탐색할 수 있어요.</div></div></li><li class="video_item _svp_item _ani_type" data-cr-exposure="vdo_lst*K" data-cr-gdid="1016616097_880000AF_000000000000000002011808" data-cr-gparam="3:1:0:1111|880000AF_000000000000000002011808:0520002011808|0:0:0:1:3" data-cr-rank="3" data-cr-url="http://news.naver.com/main/read.naver?mode=LPOD&amp;mid=tvh&amp;oid=052&amp;aid=0002011808"><div class="video_bx _aniitem _video_preview" data-video-selector=".api_mov"><div class="thumb_area"><a class="link _svp_trigger" data-api="https://s.search.naver.com/p/video/47/search.naver?where=inkey&amp;vid=880000AF_000000000000000002011808:0520002011808" data-cr-area="thu" data-is-visible-close-btn="false" href="http://news.naver.com/main/read.naver?mode=LPOD&amp;mid=tvh&amp;oid=052&amp;aid=0002011808"><img class="thumb api_get api_img" he ...
# <video class="api_mov" height="104" loop="true" muted="" playsinline="" preload="none" webkit-playsinline="" width="184">
# <source src="https://a01-g-naver-vod.akamaized.net/navertv/c/read/v2/VOD_ALPHA/navertv_2024_03_18_1951/f0a64c79-e50d-11ee-bec9-a0369ffdf77c.mp4?__gda__=1710788325_c3d47e334a14d754033e378fe6864555" type="video/mp4"/></video>
# <span class="mod_thumb_mask"><i class="spnew api_ico_play3">동영상</i></span>
# <span class="api_badge_video"><i class="spnew ico_thumbnail"></i>주요장면 2개</span>
# <span aria-label="재생시간 01:07" class="time">01:07</span>
# </a><a class="close_mask _svp_close" href="#" onclick='return tCR("a=vdo_lst*K.close&amp;r=3&amp;i=1016616097_880000AF_000000000000000002011808&amp;g="+urlencode("3:1:0:1111|880000AF_000000000000000002011808:0520002011808|0:0:0:1:3")+"")' role="button"><span class="close_txt">닫기<i class="spnew ico_close_s"></i></span></a></div><div class="info_area"><div class="api_save_group _keep_wrap"><a aria-pressed="false" class="btn_save _keep_trigger" data-cr-off="a=vdo_lst*K.kep&amp;r=&amp;i=" data-cr-on="a=vdo_lst*K.kep&amp;r=&amp;i=" data-url="http://news.naver.com/main/read.naver?mode=LPOD&amp;mid=tvh&amp;oid=052&amp;aid=0002011808" href="#" role="button"><i class="spnew ico_save">문서 저장하기</i></a><div class="api_ly_save _keep_save_layer"><a class="spnew_af item item_save _keep_save" data-cr-off="a=vdo_lst*K.kepoff&amp;r=&amp;i=" data-cr-on="a=vdo_lst*K.kepon&amp;r=&amp;i=" href="#" role="button">Keep에 저장</a>
# <a class="spnew_af item item_quick" href="https://keep.naver.com/" onclick='return goOtherCR(this,"a=vdo_lst*K.kephome&amp;r=&amp;i=&amp;u="+urlencode(this.href))' target="_blank">Keep 바로가기</a></div></div><a class="info_title" href="http://news.naver.com/main/read.naver?mode=LPOD&amp;mid=tvh&amp;oid=052&amp;aid=0002011808" onclick='return goOtherCR(this,"a=vdo_lst*K.tit&amp;r=3&amp;i=1016616097_880000AF_000000000000000002011808&amp;g="+urlencode("3:1:0:1111|880000AF_000000000000000002011808:0520002011808|0:0:0:1:3")+"&amp;u="+urlencode(this.href))' target="_blank">[<mark>날씨</mark>] 내일 돌풍·벼락 동반한 비·눈...꽃샘추위 기승</a><div class="info_sub"><div class="desc_group"><a class="channel" href="http://www.ytn.co.kr/" onclick='return goOtherCR(this,"a=vdo_lst*K.cha&amp;r=3&amp;i=1016616097_880000AF_000000000000000002011808&amp;g="+urlencode("3:1:0:1111|880000AF_000000000000000002011808:0520002011808|0:0:0:1:3")+"&amp;u="+urlencode(this.href))' target="_blank">YTN</a></div><div class="desc_group"><a class="origin" href="http://news.naver.com" onclick='return goOtherCR(this,"a=vdo_lst*K.sou&amp;r=3&amp;i=1016616097_880000AF_000000000000000002011808&amp;g="+urlencode("3:1:0:1111|880000AF_000000000000000002011808:0520002011808|0:0:0:1:3")+"&amp;u="+urlencode(this.href))' target="_blank">네이버 뉴스</a>
# <span class="desc">1시간 전</span></div></div></div></div><div class="video_scene_bx"><div class="video_scene_wrap type_thumbnail"><div class="video_scene"><a class="title_link _expand" href="#" role="button"><div class="title_thumb"><div class="thumb_box"><img class="thumb" height="23" onerror="naver.common.handleImgError(this)" src="https://search.pstatic.net/common/?src=https%3A%2F%2Fvideo-search-phinf.pstatic.net%2FMjAyNDAzMThfMjU5%2FMDAxNzEwNzU1NzIwNzIy.DuZRdUYZ4BkrgVdGULIKuoJiWUQyKPID4lDU99PDMFgg.iZBc2uVvuThxa2Pr-VY3Ry6PE9Nh6_9BbspWXRxIFYIg.JPEG%2FD481DFEF32B6955E0611729976DA94353DCC_0.jpg&amp;type=ac176_100" width="40"/></div></div><div class="title_txt">위 동영상의 주요 장면 2개</div><i class="spnew ico_fold">펼치기</i></a><div class="video_link_wrap"><div class="video_common_player_wrap _svp_target"></div></div><div class="stamp_list_wrap"><div class="api_pcpg_wrap"><div class="api_flicking_wrap _scene_conveyer_root" data-fit-type="exact"><div class="flick_bx"><a class="stamp_item _svp_trigger _scene" data-api="https://s.search.naver.com/p/video/47/search.naver?where=inkey&amp;vid=880000AF_000000000000000002011808:0520002011808" data-cr-area="chapter" data-cr-gparam="3:1:0:1111|880000AF_000000000000000002011808:0520002011808:17|0:0:0:1:3" data-is-visible-close-btn="false" data-seek-time="17" href=""><div class="stamp_thumb_area"><img class="thumb" height="52" onerror="naver.common.handleImgError(this)" src="https://search.pstatic.net/common/?src=https%3A%2F%2Fvideo-search-phinf.pstatic.net%2FMjAyNDAzMThfMjU5%2FMDAxNzEwNzU1NzIwNzIy.DuZRdUYZ4BkrgVdGULIKuoJiWUQyKPID4lDU99PDMFgg.iZBc2uVvuThxa2Pr-VY3Ry6PE9Nh6_9BbspWXRxIFYIg.JPEG%2FD481DFEF32B6955E0611729976DA94353DCC_0.jpg&amp;type=ac176_100" width="91"/></div><div class="stamp_info_area"><div class="stamp_time">00:17</div><div class="dsc">예상 강우량</div></div></a></div><div class="flick_bx"><a class="stamp_item _svp_trigger _scene" data-api="https://s.search.naver.com/p/video/47/search.naver?where=inkey&amp;vid=880000AF_000000000000000002011808:0520002011808" data-cr-area="chapter" data-cr-gparam="3:1:0:1111|880000AF_000000000000000002011808:0520002011808:42|0:0:0:1:3" data-is-visible-close-btn="false" data-seek-time="42" href=""><div class="stamp_thumb_area"><img class="thumb" height="52" onerror="naver.common.handleImgError(this)" src="https://search.pstatic.net/common/?src=https%3A%2F%2Fvideo-search-phinf.pstatic.net%2FMjAyNDAzMThfMTU4%2FMDAxNzEwNzU1NzIwNzc3.TppC8jmnnGDc0b0XjVIKjg-8FxZIjl1n0VHQpDZdLmUg.3N8vXgldW8ggAE1TJje_iJYAOtqQKNzNVou5mnAutAEg.JPEG%2FD481DFEF32B6955E0611729976DA94353DCC_0.jpg&amp;type=ac176_100" width="91"/></div><div class="stamp_info_area"><div class="stamp_time">00:42</div><div class="dsc">주간 날씨</div></div></a></div></div><div class="api_btn_page"><div class="btn_prev _prev" style="display: none;"><a class="btn" href="#" onclick='return tCR("a=vdo_lst.leftbt&amp;r=0&amp;i=&amp;g=")' role="button"><i class="spnew ico_arr">이전</i></a></div><div class="btn_next _next"><a class="btn" href="#" onclick='return tCR("a=vdo_lst.rightbt&amp;r=0&amp;i=&amp;g=")' role="button"><i class="spnew ico_arr">다음</i></a></div></div></div></div></div></div><div class="mod_ly_notice">영상 내 주요 장면을 탐색할 수 있어요.</div></div></li><li class="video_item _svp_item _ani_type" data-cr-exposure="vdo_lst*K" data-cr-gdid="1016616097_88000114_000000000000000011683372" data-cr-gparam="4:1:0:1111|88000114_000000000000000011683372:0560011683372|0:0:0:1:4" data-cr-rank="4" data-cr-url="http://news.naver.com/main/read.naver?mode=LPOD&amp;mid=tvh&amp;oid=056&amp;aid=0011683372"><div class="video_bx _aniitem _video_preview" data-video-selector=".api_mov"><div class="thumb_area"><a class="link _svp_trigger" data-api="https://s.search.naver.com/p/video/47/search.naver?where=inkey&amp;vid=88000114_000000000000000011683372:0560011683372" data-cr-area="thu" data-is-visible-close-btn="false" href="http://news.naver.com/main/read.naver?mode=LPOD&amp;mid=tvh&amp;oid=056&amp;aid=0011683372"><img class="thumb api_get api_ ...
# <video class="api_mov" height="104" loop="true" muted="" playsinline="" preload="none" webkit-playsinline="" width="184">
# <source src="https://a01-g-naver-vod.akamaized.net/navertv/c/read/v2/VOD_ALPHA/navertv_2024_03_18_1404/db08e19d-e50a-11ee-bf6b-a0369ffabcc4.mp4?__gda__=1710786988_911e6a13fd750a60e81893c7d453b3b8" type="video/mp4"/></video>
# <span class="mod_thumb_mask"><i class="spnew api_ico_play3">동영상</i></span>
# <span class="api_badge_video"><i class="spnew ico_thumbnail"></i>주요장면 4개</span>
# <span aria-label="재생시간 01:06" class="time">01:06</span>
# </a><a class="close_mask _svp_close" href="#" onclick='return tCR("a=vdo_lst*K.close&amp;r=4&amp;i=1016616097_88000114_000000000000000011683372&amp;g="+urlencode("4:1:0:1111|88000114_000000000000000011683372:0560011683372|0:0:0:1:4")+"")' role="button"><span class="close_txt">닫기<i class="spnew ico_close_s"></i></span></a></div><div class="info_area"><div class="api_save_group _keep_wrap"><a aria-pressed="false" class="btn_save _keep_trigger" data-cr-off="a=vdo_lst*K.kep&amp;r=&amp;i=" data-cr-on="a=vdo_lst*K.kep&amp;r=&amp;i=" data-url="http://news.naver.com/main/read.naver?mode=LPOD&amp;mid=tvh&amp;oid=056&amp;aid=0011683372" href="#" role="button"><i class="spnew ico_save">문서 저장하기</i></a><div class="api_ly_save _keep_save_layer"><a class="spnew_af item item_save _keep_save" data-cr-off="a=vdo_lst*K.kepoff&amp;r=&amp;i=" data-cr-on="a=vdo_lst*K.kepon&amp;r=&amp;i=" href="#" role="button">Keep에 저장</a>
# <a class="spnew_af item item_quick" href="https://keep.naver.com/" onclick='return goOtherCR(this,"a=vdo_lst*K.kephome&amp;r=&amp;i=&amp;u="+urlencode(this.href))' target="_blank">Keep 바로가기</a></div></div><a class="info_title" href="http://news.naver.com/main/read.naver?mode=LPOD&amp;mid=tvh&amp;oid=056&amp;aid=0011683372" onclick='return goOtherCR(this,"a=vdo_lst*K.tit&amp;r=4&amp;i=1016616097_88000114_000000000000000011683372&amp;g="+urlencode("4:1:0:1111|88000114_000000000000000011683372:0560011683372|0:0:0:1:4")+"&amp;u="+urlencode(this.href))' target="_blank">[퇴근길 <mark>날씨</mark>] 내일 전국에 비·눈…강원산지에 대설</a><div class="info_sub"><div class="desc_group"><a class="channel" href="http://news.kbs.co.kr/" onclick='return goOtherCR(this,"a=vdo_lst*K.cha&amp;r=4&amp;i=1016616097_88000114_000000000000000011683372&amp;g="+urlencode("4:1:0:1111|88000114_000000000000000011683372:0560011683372|0:0:0:1:4")+"&amp;u="+urlencode(this.href))' target="_blank">KBS</a></div><div class="desc_group"><a class="origin" href="http://news.naver.com" onclick='return goOtherCR(this,"a=vdo_lst*K.sou&amp;r=4&amp;i=1016616097_88000114_000000000000000011683372&amp;g="+urlencode("4:1:0:1111|88000114_000000000000000011683372:0560011683372|0:0:0:1:4")+"&amp;u="+urlencode(this.href))' target="_blank">네이버 뉴스</a>
# <span class="desc">1시간 전</span></div></div></div></div><div class="video_scene_bx"><div class="video_scene_wrap type_thumbnail"><div class="video_scene"><a class="title_link _expand" href="#" role="button"><div class="title_thumb"><div class="thumb_box"><img class="thumb" height="23" onerror="naver.common.handleImgError(this)" src="https://search.pstatic.net/common/?src=https%3A%2F%2Fvideo-search-phinf.pstatic.net%2FMjAyNDAzMThfMTIz%2FMDAxNzEwNzU0NjQ4MTEy.zv67zxr_VwYR9dnqNgZdaUUtYf16HxrU_eU0La7vWeYg.V3K5wOu2lQI-20_schdgcYF2alKL-Bl7qeHL9a_44tEg.JPEG%2FCAA495672D3753A54A6C3732FB974D694760_0.jpg&amp;type=ac176_100" width="40"/></div></div><div class="title_txt">위 동영상의 주요 장면 4개</div><i class="spnew ico_fold">펼치기</i></a><div class="video_link_wrap"><div class="video_common_player_wrap _svp_target"></div></div><div class="stamp_list_wrap"><div class="api_pcpg_wrap"><div class="api_flicking_wrap _scene_conveyer_root" data-fit-type="exact"><div class="flick_bx"><a class="stamp_item _svp_trigger _scene" data-api="https://s.search.naver.com/p/video/47/search.naver?where=inkey&amp;vid=88000114_000000000000000011683372:0560011683372" data-cr-area="chapter" data-cr-gparam="4:1:0:1111|88000114_000000000000000011683372:0560011683372:2|0:0:0:1:4" data-is-visible-close-btn="false" data-seek-time="2" href=""><div class="stamp_thumb_area"><img class="thumb" height="52" onerror="naver.common.handleImgError(this)" src="https://search.pstatic.net/common/?src=https%3A%2F%2Fvideo-search-phinf.pstatic.net%2FMjAyNDAzMThfMTIz%2FMDAxNzEwNzU0NjQ4MTEy.zv67zxr_VwYR9dnqNgZdaUUtYf16HxrU_eU0La7vWeYg.V3K5wOu2lQI-20_schdgcYF2alKL-Bl7qeHL9a_44tEg.JPEG%2FCAA495672D3753A54A6C3732FB974D694760_0.jpg&amp;type=ac176_100" width="91"/></div><div class="stamp_info_area"><div class="stamp_time">00:02</div><div class="dsc">건조 특보</div></div></a></div><div class="flick_bx"><a class="stamp_item _svp_trigger _scene" data-api="https://s.search.naver.com/p/video/47/search.naver?where=inkey&amp;vid=88000114_000000000000000011683372:0560011683372" data-cr-area="chapter" data-cr-gparam="4:1:0:1111|88000114_000000000000000011683372:0560011683372:24|0:0:0:1:4" data-is-visible-close-btn="false" data-seek-time="24" href=""><div class="stamp_thumb_area"><img class="thumb" height="52" onerror="naver.common.handleImgError(this)" src="https://search.pstatic.net/common/?src=https%3A%2F%2Fvideo-search-phinf.pstatic.net%2FMjAyNDAzMThfMjQw%2FMDAxNzEwNzU0NjQ4MjY3.ksw4TfTStjVl0UDUaOoZfuxCtcuHQ0HcvPxF1_oNk9kg.d9dODhiHbfZVUsNbJJoL6ozlEpzKheIA9ksbWUx34tAg.JPEG%2FCAA495672D3753A54A6C3732FB974D694760_0.jpg&amp;type=ac176_100" width="91"/></div><div class="stamp_info_area"><div class="stamp_time">00:24</div><div class="dsc">눈</div></div></a></div><div class="flick_bx"><a class="stamp_item _svp_trigger _scene" data-api="https://s.search.naver.com/p/video/47/search.naver?where=inkey&amp;vid=88000114_000000000000000011683372:0560011683372" data-cr-area="chapter" data-cr-gparam="4:1:0:1111|88000114_000000000000000011683372:0560011683372:54|0:0:0:1:4" data-is-visible-close-btn="false" data-seek-time="54" href=""><div class="stamp_thumb_area"><img class="thumb" height="52" onerror="naver.common.handleImgError(this)" src="https://search.pstatic.net/common/?src=https%3A%2F%2Fvideo-search-phinf.pstatic.net%2FMjAyNDAzMThfMjU5%2FMDAxNzEwNzU0NjQ4NDEz.oZ9zU9VpyR_XGAohOOMxR46kF43FtyHeYeGH7UVYuMIg.fSnpvgWMuV_EGPAtQIDSAp-gaSVc1p6SDzEvUCpkO2gg.JPEG%2FCAA495672D3753A54A6C3732FB974D694760_0.jpg&amp;type=ac176_100" width="91"/></div><div class="stamp_info_area"><div class="stamp_time">00:54</div><div class="dsc">해상 날씨</div></div></a></div><div class="flick_bx"><a class="stamp_item _svp_trigger _scene" data-api="https://s.search.naver.com/p/video/47/search.naver?where=inkey&amp;vid=88000114_000000000000000011683372:0560011683372" data-cr-area="chapter" data-cr-gparam="4:1:0:1111|88000114_000000000000000011683372:0560011683372:59|0:0:0:1:4" data-is-visible-close-btn="false" data-seek-time="59" href=""><div class="stamp_thum ...
# <span class="etc">더보기<i class="spnew ico_arr"></i></span></a></div></div></section><script>(function(){var e="https://ssl.pstatic.net/sstatic/fe/sfe/video/app-1.9.0.js",t=function(){var e=window.require.config({context:"search_common_modules"});e(["VideoPlayer2"],n)},n=function(){var t=window.require.config({context:"video",paths:{"@sfe/togglor":"https://ssl.pstatic.net/sstatic/au/module/togglor/togglor-1.3.1.min","@sfe/video-preview":"https://ssl.pstatic.net/sstatic/fe/sfe/video-preview/Controller_231123_a",app:e.replace(/\.js$/,"")}});define("jquery",[],function(){return jQuery}),define("@sfe/search-video-player2",[],function(){return naver.common.VideoPlayer2}),t(["jquery","app"],function(e,t){t({$root:e("._fe_video"),type:"pc",isTab:!1,report:{api:"https://s.search.naver.com/n/srm/report"}})})};naver.common.load_js(null,t,!0,60)})()</script><section class="sc_new sp_ntotal _sp_ntotal _prs_web_gen _fe_root_web_gen"><div class="api_subject_bx"><ul class="lst_total"><li class="bx"><div class="total_wrap"><div class="total_tit_group"><div class="total_source"><div class="api_save_group _keep_wrap"><a class="btn_save _keep_trigger" data-url="https://meteodays.com/ko/weather/tomorrow/seoul" href="#" onclick='tCR("a=web_gen*w.kep&amp;r=&amp;i=&amp;u=javascript")' role="button"><i class="spnew ico_save">문서 저장하기</i></a><div class="api_ly_save _keep_save_layer"><a class="spnew_af item item_save _keep_save" data-cr-off="a=web_gen*w.keepoff" data-cr-on="a=web_gen*w.keepon" href="#" role="button">Keep에 저장</a>
# <a class="spnew_af item item_quick" href="https://keep.naver.com/" onclick='goOtherCR(this,"a=web_gen*w.kep&amp;r=0&amp;i=a00000fa_44af3a0ba3dcf1ebcd9744b9%5Exq&amp;u="+urlencode(this.href))' target="_blank">Keep 바로가기</a></div></div><div class="source_box"><a class="thumb" href="https://meteodays.com/ko/weather/tomorrow/seoul" onclick='goOtherCR(this,"a=web_gen*w.link&amp;r=0&amp;i=a00000fa_44af3a0ba3dcf1ebcd9744b9%5Exq&amp;u="+urlencode(this.href))' target="_blank"><img alt="" data-lazysrc="https://search.pstatic.net/sunny?src=https%3A%2F%2Fmeteodays.com%2Ffavicon.svg&amp;type=f30_30_png_expire24" height="16" src="..." width="16"/></a><a class="txt" href="https://meteodays.com/ko/weather/tomorrow/seoul" target="_blank">
# meteodays.com<i class="divide">›</i>서울특별시<i class="divide">›</i>서울<i class="divide">›</i>내일 날씨</a></div></div></div><div class="total_group"><div class="total_tit"><a class="link_tit" href="https://meteodays.com/ko/weather/tomorrow/seoul" onclick='goOtherCR(this,"a=web_gen*w.link&amp;r=0&amp;i=a00000fa_44af3a0ba3dcf1ebcd9744b9%5Exq&amp;u="+urlencode(this.href))' target="_blank"><mark>서울</mark> <mark>내일</mark> <mark>날씨</mark> 시시각각</a></div><div class="total_dsc_wrap"><a class="api_txt_lines total_dsc type_3lines" href="https://meteodays.com/ko/weather/tomorrow/seoul" onclick='goOtherCR(this,"a=web_gen*w.link&amp;r=0&amp;i=a00000fa_44af3a0ba3dcf1ebcd9744b9%5Exq&amp;u="+urlencode(this.href))' target="_blank"><mark>내일 서울 날씨</mark>는 오늘과 비슷할 것으로 예상됩니다. 구름이 조금 끼어 쾌적하고 오늘보다 조금 더 추울 것으로 예상됩니다. 낮 기온은 43~50°, 밤 기온은 46~48° 사이가 되겠습니다. 예상 바람은 시속 10마일의 잔잔한 바람과 최대 32마일의 돌풍으로 쾌적할 것으로 예상됩니다. <mark>내일</mark>은 비나 눈이 예보되어 있지 않습니다. 아래에서 종합적인 시간별 일기 예보를 확인하세요.</a></div></div></div><div class="faq_wrap"><div class="faq_group _fold_wrap"><a aria-expanded="false" class="question_area _trigger" data-cr-area-off="a=web_gen*w.unfold" data-cr-area-on="a=web_gen*w.fold" href="#" role="button"><div class="question">내일 서울 날씨는 어떻습니까?</div><i class="spnew api_ico_fold">접기</i></a><div class="answer_area">약간의 구름과 함께 쾌적하다 오늘보다 추운 것입니다.</div></div><div class="faq_group _fold_wrap"><a aria-expanded="false" class="question_area _trigger" data-cr-area-off="a=web_gen*w.unfold" data-cr-area-on="a=web_gen*w.fold" href="#" role="button"><div class="question">내일 서울에 비가 올까요, 눈이 올까요?</div><i class="spnew api_ico_fold">접기</i></a><div class="answer_area">내일 비 또는 눈이 내릴 것으로 예보되지 않았습니다.</div></div></div></li><li class="bx"><div class="total_wrap"><div class="total_tit_group"><div class="total_source"><div class="api_save_group _keep_wrap"><a class="btn_save _keep_trigger" data-url="https://freemeteo.kr/weather/seoul/hourly-forecast/tomorrow/?gid=1835848&amp;language=korean&amp;country=south-korea" href="#" onclick='tCR("a=web_gen*w.kep&amp;r=&amp;i=&amp;u=javascript")' role="button"><i class="spnew ico_save">문서 저장하기</i></a><div class="api_ly_save _keep_save_layer"><a class="spnew_af item item_save _keep_save" data-cr-off="a=web_gen*w.keepoff" data-cr-on="a=web_gen*w.keepon" href="#" role="button">Keep에 저장</a>
# <a class="spnew_af item item_quick" href="https://keep.naver.com/" onclick='goOtherCR(this,"a=web_gen*w.kep&amp;r=1&amp;i=a00000fa_366ddd4e4e9bef6edb54b32c&amp;u="+urlencode(this.href))' target="_blank">Keep 바로가기</a></div></div><div class="source_box"><a class="thumb" href="https://freemeteo.kr/weather/seoul/hourly-forecast/tomorrow/?gid=1835848&amp;language=korean&amp;country=south-korea" onclick='goOtherCR(this,"a=web_gen*w.link&amp;r=1&amp;i=a00000fa_366ddd4e4e9bef6edb54b32c&amp;u="+urlencode(this.href))' target="_blank"><img alt="" data-lazysrc="https://search.pstatic.net/sunny?src=https%3A%2F%2Ffreemeteo.kr%2Ffavicon.ico&amp;type=f30_30_png_expire24" height="16" src="..." width="16"/></a><a class="txt" href="https://freemeteo.kr/weather/seoul/hourly-forecast/tomorrow/?gid=1835848&amp;language=korean&amp;country=south-korea" target="_blank">
# freemeteo.kr<i class="divide">›</i>weather</a></div></div></div><div class="total_group"><div class="total_tit"><a class="link_tit" href="https://freemeteo.kr/weather/seoul/hourly-forecast/tomorrow/?gid=1835848&amp;language=korean&amp;country=south-korea" onclick='goOtherCR(this,"a=web_gen*w.link&amp;r=1&amp;i=a00000fa_366ddd4e4e9bef6edb54b32c&amp;u="+urlencode(this.href))' target="_blank"><mark>날씨</mark> <mark>서울</mark> <mark>내일</mark> 시간별| freemeteo.kr</a></div><div class="total_dsc_wrap"><a class="api_txt_lines total_dsc type_3lines" href="https://freemeteo.kr/weather/seoul/hourly-forecast/tomorrow/?gid=1835848&amp;language=korean&amp;country=south-korea" onclick='goOtherCR(this,"a=web_gen*w.link&amp;r=1&amp;i=a00000fa_366ddd4e4e9bef6edb54b32c&amp;u="+urlencode(this.href))' target="_blank"><mark>날씨</mark> <mark>서울</mark>, <mark>내일</mark>, 시간별. <mark>서울</mark> <mark>내일</mark> 시간별 상세 일기 예보. 악천후 경고. freemeteo.kr</a></div></div></div><div class="source_cluster_wrap"><div class="source_cluster_list"><div class="source_item"><a class="source_title" href="https://freemeteo.kr/weather/seoul/daily-forecast/tomorrow/?gid=1835848" onclick='goOtherCR(this,"a=web_gen*w.link&amp;r=2&amp;i=a00000fa_fe7c0c1e20584871636860db%5El&amp;u="+urlencode(this.href))' target="_blank"><mark>날씨</mark> <mark>서울</mark> <mark>내일</mark> | freemeteo.kr</a><div class="source_dsc"><mark>날씨</mark> <mark>서울</mark> <mark>내일</mark>. <mark>서울</mark>, <mark>내일</mark> <mark>날씨</mark> 보기. 상세 <mark>기상</mark> 예보. 악천후 알림. freemeteo.kr</div></div></div></div><div class="total_more_wrap"><a class="total_more" href="?query=%EB%82%B4%EC%9D%BC+%EC%84%9C%EC%9A%B8+%EB%82%A0%EC%94%A8+site%3Afreemeteo.kr&amp;qvt=0&amp;where=web" onclick='goOtherCR(this,"a=web_gen*w.sramore&amp;r=&amp;i=&amp;u="+urlencode(this.href))'>관련문서 더보기<i class="spnew api_ico_arr4"></i></a></div></li><li class="bx"><div class="total_wrap"><div class="total_tit_group"><div class="total_source"><div class="api_save_group _keep_wrap"><a class="btn_save _keep_trigger" data-url="https://korean.visitseoul.net/weather" href="#" onclick='tCR("a=web_gen*w.kep&amp;r=&amp;i=&amp;u=javascript")' role="button"><i class="spnew ico_save">문서 저장하기</i></a><div class="api_ly_save _keep_save_layer"><a class="spnew_af item item_save _keep_save" data-cr-off="a=web_gen*w.keepoff" data-cr-on="a=web_gen*w.keepon" href="#" role="button">Keep에 저장</a>
# <a class="spnew_af item item_quick" href="https://keep.naver.com/" onclick='goOtherCR(this,"a=web_gen*w.kep&amp;r=3&amp;i=a00000fa_6343e8122d4247fe75e3ca64&amp;u="+urlencode(this.href))' target="_blank">Keep 바로가기</a></div></div><div class="source_box"><a class="thumb" href="https://korean.visitseoul.net/weather" onclick='goOtherCR(this,"a=web_gen*w.link&amp;r=3&amp;i=a00000fa_6343e8122d4247fe75e3ca64&amp;u="+urlencode(this.href))' target="_blank"><img alt="" data-lazysrc="https://search.pstatic.net/sunny?src=https%3A%2F%2Fkorean.visitseoul.net%2Fresources%2Ftheme%2Fbasic%2Fassets%2Fimages%2Fimg%2Fpavi_16_16.png&amp;type=f30_30_png_expire24" height="16" src="..." width="16"/></a><a class="txt" href="https://korean.visitseoul.net/weather" target="_blank">
# korean.visitseoul.net<i class="divide">›</i>weather</a></div></div></div><div class="total_group"><div class="total_tit"><a class="link_tit" href="https://korean.visitseoul.net/weather" onclick='goOtherCR(this,"a=web_gen*w.link&amp;r=3&amp;i=a00000fa_6343e8122d4247fe75e3ca64&amp;u="+urlencode(this.href))' target="_blank"><mark>서울</mark> 실시간 <mark>날씨</mark> 정보 | <mark>서울</mark>시 공식 관광정보 웹사이트</a></div><div class="total_dsc_wrap"><a class="api_txt_lines total_dsc type_3lines" href="https://korean.visitseoul.net/weather" onclick='goOtherCR(this,"a=web_gen*w.link&amp;r=3&amp;i=a00000fa_6343e8122d4247fe75e3ca64&amp;u="+urlencode(this.href))' target="_blank">오늘, <mark>내일</mark>, 이번 주 <mark>서울 날씨</mark> 알아보기. <mark>서울</mark> 일기예보. 최저/최고기온, 강수확률, 미세먼지 현황. 이번 주 <mark>서울</mark> 일기예보까지 원클릭 조회. 완벽한 <mark>서울</mark> 여행을 위해 여행 전 <mark>서울</mark> 일기예보를 확인하세요. <mark>서울</mark>관광재단 Visit <mark>Seoul</mark>에서 확인하는 실시간 <mark>날씨</mark> 정보.</a></div></div></div></li></ul><div class="mod_more_wrap"><a class="group_more" href="?nso=&amp;page=2&amp;query=%EB%82%B4%EC%9D%BC+%EC%84%9C%EC%9A%B8+%EB%82%A0%EC%94%A8&amp;sm=tab_pge&amp;start=1&amp;where=web" onclick='goOtherCR(this,"a=web_gen*w.more2&amp;r=&amp;i=&amp;u="+urlencode(this.href))'><span class="kwd">검색결과</span>
# <span class="etc">더보기<i class="spnew ico_arr"></i></span></a></div></div></section><script>(function(){var e="https://ssl.pstatic.net/sstatic/fe/sfe/commonPortal/pc_240116.js",t=function(){var t=window.require.config({context:"_fe_web_commonportal",paths:{Controller:e.replace(/\.js$/,"")}});define("jquery",[],function(){return jQuery}),t(["Controller"],function(e){var t=jQuery("._fe_root_web_gen"),n=new e(t);n.on({"tab-scroll":function(e){e.isTrusted},"content-scroll":function(e){if(e.isTrusted){var t=e.$wrapper.find("._freescroll_flicking").attr("data-log");t&&tCR(t)}},"click-infolayer-trigger-button":function(e){e.isOn}})})},n=naver.common.gv.REQUIRE_JS;naver.common.load_js(window.require?null:n,t,!0,150)})()</script><script>(function(){var e,n="_sp_ntotal",s="type_margin",t=Array.prototype.slice.call(document.querySelectorAll("section."+n));function o(e,t){return e.matches?e.matches(t):!!e.msMatchesSelector&&e.msMatchesSelector(t)}function i(e){var t=e,s=t.tagName.toLowerCase();do t=t.previousElementSibling,s=t?t.tagName.toLowerCase():"";while(t!==null&&(s==="script"||s==="link"))return t!==null&&s==="section"&&o(t,"."+n)}for(e=0;e<t.length;++e)i(t[e])&&t[e].classList.add(s)})()</script><link href="https://ssl.pstatic.net/sstatic/search/pc/css/sp_ncafe_used_230921n.css" rel="stylesheet"/><section class="sc_new sp_ncafe_used _prs_shc _au_preowned_collection"><div class="api_subject_bx" style="position:relative;"><div class="mod_title_area _modal_wrap"><div class="title_wrap"><h2 class="title">카페 중고거래</h2><span class="sub"><a aria-pressed="false" class="api_ad_link _trigger" href="#" onclick='return tCR("a=shc.info&amp;r=&amp;i=&amp;u=javascript")' role="button"><i class="spnew api_ico_alert">이 정보가 표시된 이유</i></a></span></div><div class="ly_api_info _content"><p class="dsc">네이버 카페의 상품등록게시판에 등록된 게시글(중고거래, 공동구매 등)을 검색결과에 제공합니다.</p><button class="btn_close _trigger" onclick='return tCR("a=shc.infoclose&amp;r=&amp;i=&amp;u=javascript")' type="button"><i class="spnew ico_close">정보확인 레이어 닫기</i></button></div></div><div class="api_tab_wrap _filter_wrap"><div class="api_tab_list"><div class="tab_list" role="tablist"><div class="tab_bx" role="presentation"><a aria-selected="true" class="item" data-cr-minor="tap" data-tab-key="subtab" data-tab-value="8" href="#" onclick='return tCR("a=shc*a.tap&amp;r=&amp;i=&amp;u=javascript")' role="tab"><span class="txt">전체</span></a></div><div class="tab_bx" role="presentation"><a aria-selected="false" class="item" data-cr-minor="tap" data-tab-key="subtab" data-tab-value="1" href="#" onclick='return tCR("a=shc*d.tap&amp;r=&amp;i=&amp;u=javascript")' role="tab"><span class="txt">직거래</span></a></div><div class="tab_bx" role="presentation"><a aria-selected="false" class="item" data-cr-minor="tap" data-tab-key="subtab" data-tab-value="2" href="#" onclick='return tCR("a=shc*p.tap&amp;r=&amp;i=&amp;u=javascript")' role="tab"><span class="txt">택배ㆍ기타</span></a></div></div></div></div><div class="filter_wrap _filter_wrap"><div class="api_pcpg_wrap mod_group_tag _conveyer_wrap"><div class="api_flicking_wrap _conveyer_flicking"><div class="flick_bx"><a aria-pressed="false" class="mod_tag" data-cr-minor="safe" data-filter-key="payment" data-filter-toggle="true" data-filter-value="1" href="#" role="button"><span class="t">안전결제</span></a></div><div class="flick_bx"><a aria-pressed="false" class="mod_tag" data-cr-minor="direct" data-filter-key="payment" data-filter-toggle="true" data-filter-value="0" href="#" role="button"><span class="t">일반결제</span></a></div><div class="flick_bx _location_filter"><a aria-pressed="false" class="mod_tag _location_filter_trigger" data-cr-minor="region" data-value="" href="#" role="button"><span class="t"><span class="_location_filter_text">지역<i class="spnew ico_txt_fold">펼치기</i><i class="spnew ico_txt_unfold">접기</i></span></span></a></div><div class="flick_bx"><a aria-pressed="false" class="mod_tag" data-cr-minor="unopen" data-filter-key="state" data-filter-toggle="true" data-filter- ...
# <strong class="tit_message">검색결과가 없습니다.</strong><p class="dsc_message">옵션을 재선택 하시거나 초기화 해보시기 바랍니다.</p><a class="btn_retry _reset" href="#"><i class="spnew api_ico_retry"></i>초기화</a></div></div><div class="error_area _error" style="display:none"><div class="api_error_wrap"><i class="spnew api_ico_alert_big"></i>
# ...
# <em class="badge"><span class="txt">3월 인기</span></em></div><div class="info_area"><div class="name">천정형시스템에어컨</div></div></a></div><div class="flick_bx"><a class="item_card" href="?where=nexearch&amp;mra=U1BI&amp;sm=tab_clk.shp&amp;query=%eb%b2%bd%ea%b1%b8%ec%9d%b4%ec%97%90%ec%96%b4%ec%bb%a86%ed%8f%89" onclick="return goOtherCR(this,'a=shX_ssC*w.kyw&amp;r=8&amp;i=SYS-0000000012879070.98226stj_91E48706D16D473D27DD0D00A7994A5A&amp;g=%7B%22bid%22%3A%22SYS-0000000012879070%22%2C%22docRank%22%3A%228%22%7D&amp;u='+urlencode(this.href))"><div class="thumb_area"><img class="api_get" height="84" onerror="naver.common.handleImgError(this)" src="https://search.pstatic.net/common/?src=https%3A%2F%2Fshopping-phinf.pstatic.net%2Fmain_8234127%2F82341279729.22.jpg&amp;type=f174_174" width="84"/>
# <em class="badge"><span class="txt">3월 인기</span></em></div><div class="info_area"><div class="name">벽걸이에어컨6평</div></div></a></div><div class="flick_bx"><a class="item_card" href="?where=nexearch&amp;mra=U1BI&amp;sm=tab_clk.shp&amp;query=%eb%b8%94%eb%a3%a8%ec%97%90%ec%96%b4%ed%95%84%ed%84%b0" onclick="return goOtherCR(this,'a=shX_ssC*w.kyw&amp;r=9&amp;i=SYS-0000000012879070.98226stj_81EACBAB5C615A9B4F69FD7A2E2C97D4&amp;g=%7B%22bid%22%3A%22SYS-0000000012879070%22%2C%22docRank%22%3A%229%22%7D&amp;u='+urlencode(this.href))"><div class="thumb_area"><img class="api_get" height="84" onerror="naver.common.handleImgError(this)" src="https://search.pstatic.net/common/?src=https%3A%2F%2Fshopping-phinf.pstatic.net%2Fmain_8267844%2F82678442747.6.jpg&amp;type=f174_174" width="84"/></div><div class="info_area"><div class="name">블루에어필터</div></div></a></div><div class="flick_bx"><a class="item_card" href="?where=nexearch&amp;mra=U1BI&amp;sm=tab_clk.shp&amp;query=%eb%b0%9c%eb%ae%a4%eb%8b%a4%ec%97%90%ec%96%b4%ec%97%94%ec%a7%84%ed%95%84%ed%84%b0" onclick="return goOtherCR(this,'a=shX_ssC*w.kyw&amp;r=10&amp;i=SYS-0000000012879070.98226stj_D7583D8951CFFF2B18125E6888C514DA&amp;g=%7B%22bid%22%3A%22SYS-0000000012879070%22%2C%22docRank%22%3A%2210%22%7D&amp;u='+urlencode(this.href))"><div class="thumb_area"><img class="api_get" height="84" onerror="naver.common.handleImgError(this)" src="https://search.pstatic.net/common/?src=https%3A%2F%2Fshopping-phinf.pstatic.net%2Fmain_8229664%2F82296641520.15.jpg&amp;type=f174_174" width="84"/></div><div class="info_area"><div class="name">발뮤다에어엔진필터</div></div></a></div><div class="flick_bx"><a class="item_card" href="?where=nexearch&amp;mra=U1BI&amp;sm=tab_clk.shp&amp;query=%ec%9e%90%eb%8f%99%ec%b0%a8%eb%94%94%ed%93%a8%ec%a0%80" onclick="return goOtherCR(this,'a=shX_ssC*w.kyw&amp;r=11&amp;i=SYS-0000000012879070.98226stj_56C0326685AFBCED47CE8C6A71606D3F&amp;g=%7B%22bid%22%3A%22SYS-0000000012879070%22%2C%22docRank%22%3A%2211%22%7D&amp;u='+urlencode(this.href))"><div class="thumb_area"><img class="api_get" height="84" onerror="naver.common.handleImgError(this)" src="https://search.pstatic.net/common/?src=https%3A%2F%2Fshopping-phinf.pstatic.net%2Fmain_8275557%2F82755571933.11.jpg&amp;type=f174_174" width="84"/></div><div class="info_area"><div class="name">자동차디퓨저</div></div></a></div><div class="flick_bx"><a class="item_card" href="?where=nexearch&amp;mra=U1BI&amp;sm=tab_clk.shp&amp;query=%ec%82%bc%ec%84%b1%ec%97%90%ec%96%b4%ec%bb%a81%eb%93%b1%ea%b8%89" onclick="return goOtherCR(this,'a=shX_ssC*w.kyw&amp;r=12&amp;i=SYS-0000000012879070.98226stj_D4EBEEFA7C30963B328278261B8B1862&amp;g=%7B%22bid%22%3A%22SYS-0000000012879070%22%2C%22docRank%22%3A%2212%22%7D&amp;u='+urlencode(this.href))"><div class="thumb_area"><img class="api_get" height="84" onerror="naver.common.handleImgError(this)" src="https://search.pstatic.net/common/?src=https%3A%2F%2Fshopping-phinf.pstatic.net%2Fmain_3243525%2F32435254618.20230106135447.jpg&amp;type=f174_174" width="84"/></div><div class="info_area"><div class="name">삼성에어컨1등급</div></div></a></div><div class="flick_bx"><a class="item_card" href="?where=nexearch&amp;mra=U1BI&amp;sm=tab_clk.shp&amp;query=%ec%b0%a8%eb%9f%89%eb%94%94%ed%93%a8%ec%a0%80" onclick="return goOtherCR(this,'a=shX_ssC*w.kyw&amp;r=13&amp;i=SYS-0000000012879070.98226stj_C1F90BD7897F3DAB1940D475BB6494A1&amp;g=%7B%22bid%22%3A%22SYS-0000000012879070%22%2C%22docRank%22%3A%2213%22%7D&amp;u='+urlencode(this.href))"><div class="thumb_area"><img class="api_get" height="84" onerror="naver.common.handleImgError(this)" src="https://search.pstatic.net/common/?src=https%3A%2F%2Fshopping-phinf.pstatic.net%2Fmain_2776501%2F27765010523.20230712122951.jpg&amp;type=f174_174" width="84"/>
# <em class="badge"><span class="txt">봄 인기</span></em></div><div class="info_area"><div class="name">차량디퓨저</div></div></a></div><div class="flick_bx"><a class="item_card" href="?where=nexearch&amp;mra=U1BI&amp;sm=tab_clk.shp&amp;query=%ec%a1%b0%eb%a7%90%eb%a1%a0%ec%b0%a8%eb%9f%89%eb%b0%a9%ed%96%a5%ec%a0%9c" onclick="return goOtherCR(this,'a=shX_ssC*w.kyw&amp;r=14&amp;i=SYS-0000000012879070.98226stj_5EB45697E8625F6D5E2E2F79B5ABF485&amp;g=%7B%22bid%22%3A%22SYS-0000000012879070%22%2C%22docRank%22%3A%2214%22%7D&amp;u='+urlencode(this.href))"><div class="thumb_area"><img class="api_get" height="84" onerror="naver.common.handleImgError(this)" src="https://search.pstatic.net/common/?src=https%3A%2F%2Fshopping-phinf.pstatic.net%2Fmain_8454391%2F84543919273.32.jpg&amp;type=f174_174" width="84"/>
# <em class="badge"><span class="txt">봄 인기</span></em></div><div class="info_area"><div class="name">조말론차량방향제</div></div></a></div><div class="flick_bx"><a class="item_card" href="?where=nexearch&amp;mra=U1BI&amp;sm=tab_clk.shp&amp;query=%eb%af%b8%ec%8a%a4%ed%84%b0%ec%95%a4%eb%af%b8%ec%84%b8%ec%8a%a4" onclick="return goOtherCR(this,'a=shX_ssC*w.kyw&amp;r=15&amp;i=SYS-0000000012879070.98226stj_0E18174BD0D5F92B86F66094EFB21479&amp;g=%7B%22bid%22%3A%22SYS-0000000012879070%22%2C%22docRank%22%3A%2215%22%7D&amp;u='+urlencode(this.href))"><div class="thumb_area"><img class="api_get" height="84" onerror="naver.common.handleImgError(this)" src="https://search.pstatic.net/common/?src=https%3A%2F%2Fshopping-phinf.pstatic.net%2Fmain_1001784%2F10017842540.22.jpg&amp;type=f174_174" width="84"/></div><div class="info_area"><div class="name">미스터앤미세스</div></div></a></div><div class="flick_bx"><a class="item_card" href="?where=nexearch&amp;mra=U1BI&amp;sm=tab_clk.shp&amp;query=%ec%b0%a8%eb%9f%89%ec%9a%a9%ed%83%88%ec%b7%a8%ec%a0%9c" onclick="return goOtherCR(this,'a=shX_ssC*w.kyw&amp;r=16&amp;i=SYS-0000000012879070.98226stj_0FD4AD114BD683769B5669E1F40E953C&amp;g=%7B%22bid%22%3A%22SYS-0000000012879070%22%2C%22docRank%22%3A%2216%22%7D&amp;u='+urlencode(this.href))"><div class="thumb_area"><img class="api_get" height="84" onerror="naver.common.handleImgError(this)" src="https://search.pstatic.net/common/?src=https%3A%2F%2Fshopping-phinf.pstatic.net%2Fmain_8639933%2F86399334090.6.jpg&amp;type=f174_174" width="84"/></div><div class="info_area"><div class="name">차량용탈취제</div></div></a></div><div class="flick_bx"><a class="item_card" href="?where=nexearch&amp;mra=U1BI&amp;sm=tab_clk.shp&amp;query=%ec%95%84%ec%bf%a0%ec%95%84%eb%94%94%ed%8c%8c%eb%a5%b4%eb%a7%88%ec%b0%a8%eb%9f%89%ec%9a%a9" onclick="return goOtherCR(this,'a=shX_ssC*w.kyw&amp;r=17&amp;i=SYS-0000000012879070.98226stj_9D94E9CCEA06C9F01CD6AC9426201984&amp;g=%7B%22bid%22%3A%22SYS-0000000012879070%22%2C%22docRank%22%3A%2217%22%7D&amp;u='+urlencode(this.href))"><div class="thumb_area"><img class="api_get" height="84" onerror="naver.common.handleImgError(this)" src="https://search.pstatic.net/common/?src=https%3A%2F%2Fshopping-phinf.pstatic.net%2Fmain_8515482%2F85154822009.jpg&amp;type=f174_174" width="84"/></div><div class="info_area"><div class="name">아쿠아디파르마차량용</div></div></a></div><div class="flick_bx"><a class="item_card" href="?where=nexearch&amp;mra=U1BI&amp;sm=tab_clk.shp&amp;query=%ec%b0%a8%eb%9f%89%ec%9a%a9%eb%b0%a9%ed%96%a5%ec%a0%9c" onclick="return goOtherCR(this,'a=shX_ssC*w.kyw&amp;r=18&amp;i=SYS-0000000012879070.98226stj_BBDF4CECF5B9422315D1A21BBCD38988&amp;g=%7B%22bid%22%3A%22SYS-0000000012879070%22%2C%22docRank%22%3A%2218%22%7D&amp;u='+urlencode(this.href))"><div class="thumb_area"><img class="api_get" height="84" onerror="naver.common.handleImgError(this)" src="https://search.pstatic.net/common/?src=https%3A%2F%2Fshopping-phinf.pstatic.net%2Fmain_2713754%2F27137540258.20231023140627.jpg&amp;type=f174_174" width="84"/></div><div class="info_area"><div class="name">차량용방향제</div></div></a></div><div class="flick_bx"><a class="item_card" href="?where=nexearch&amp;mra=U1BI&amp;sm=tab_clk.shp&amp;query=%ed%93%a8%eb%a6%ac%ec%bc%80%ec%96%b4" onclick="return goOtherCR(this,'a=shX_ssC*w.kyw&amp;r=19&amp;i=SYS-0000000012879070.98226stj_3318F9F7733D98527DFC88F8FD737F1D&amp;g=%7B%22bid%22%3A%22SYS-0000000012879070%22%2C%22docRank%22%3A%2219%22%7D&amp;u='+urlencode(this.href))"><div class="thumb_area"><img class="api_get" height="84" onerror="naver.common.handleImgError(this)" src="https://search.pstatic.net/common/?src=https%3A%2F%2Fshopping-phinf.pstatic.net%2Fmain_3860773%2F38607734618.20230313112041.jpg&amp;type=f174_174" width="84"/></div><div class="info_area"><div class="name">퓨리케어</div></div></a></div><div class="flick_bx"><a class="item_card" href="?where=nexearch&amp;mra=U1BI&amp;sm=tab_clk.shp&amp;query=%eb%b2%bd%ea%b1%b8%ec%9d%b4%ec%9d%b8%eb%b2%84%ed%84%b0%ec%97%90%ec%96%b4%ec%bb%a8" o ...
# <strong class="tit_message">죄송합니다. 일시적인 오류입니다.</strong><p class="dsc_message">잠시 후 다시 시도해주십시오.</p><a class="btn_retry _retry" href="javascript:;"><i class="spnew api_ico_retry"></i>재시도</a></div></div></div></div></section><script>(function(){var e="https://ssl.pstatic.net/sstatic/fe/sfe/smartblock/pc/Controller.min_230920.js",t=function(){var t=window.require.config({paths:{Controller:e.replace(/\.js$/,"")}}),n=jQuery("._fe_smartblock_shop_weather_2th");t(["Controller"],function(e){var t=new e({$base:n,response:"block.html"});t.on({})})},n=naver.common.gv.REQUIRE_JS;naver.common.load_js(window.require?null:n,t,!0,150)})()</script><section class="sc_new"> <div class="api_subject_bx"> <div class="api_common_banner"> <a class="spnew_bf item" href="https://mkt.naver.com/p1/atrb?channel_id=naver_pcsearchmktbanner&amp;campaign_id=2402-travel-002&amp;target=https%3A%2F%2Fsearch.naver.com%2Fsearch.naver%3Fmra%3DUlJUX1RJTQ%3D%3D%26where%3Dnexearch%26sm%3Dtop_hty%26fbm%3D0%26ie%3Dutf8%26query%3D%25EB%25B4%2584%25EC%2597%25AC%25ED%2596%2589%25EC%25A7%2580%25EC%25B6%2594%25EC%25B2%259C%26dtm_source%3Dnaver_pcsearchmktbanner%26dtm_medium%3Dmktatrb_etc%26dtm_campaign%3D2402-travel-002" nocr="" onclick="return goOtherCR(this, 'a=bnr.link1&amp;r=1&amp;i=&amp;u=' + urlencode(this.href));"> <div class="ico_area"><img alt="" class="ico" height="36" src="https://csearch-phinf.pstatic.net/20240228_31/1709100588557RRkaN_PNG/760_31963112_marketing_banner_pc_icon_0_1709100588542.png" width="36"/></div> <div class="dsc_area"> <strong class="elss tit">봄바람 살랑이면 생각나는 곳</strong> <p class="elss dsc">국내 봄 여행지 모아보기</p> </div> </a> <a class="spnew_bf item" href="https://mkt.naver.com/p1/atrb?channel_id=naver_pcsearchmktbanner&amp;campaign_id=2309-cue-001&amp;material=&amp;target=https%3A%2F%2Fcue.search.naver.com%2F%3Ffrom%3Dsearch_pc2nd" nocr="" onclick="return goOtherCR(this, 'a=bnr.link2&amp;r=2&amp;i=&amp;u=' + urlencode(this.href));" target="_blank"> <div class="ico_area"><img alt="" class="ico" height="36" src="https://csearch-phinf.pstatic.net/20231117_138/1700187409948YGazA_PNG/760_31963112_marketing_banner_pc_icon_1_1700187409320.png" width="36"/></div> <div class="dsc_area"> <strong class="elss tit">AI 검색, 아직 안 써봤다면?</strong> <p class="elss dsc">네이버 Cue: 사전 신청하기</p> </div> </a> <a class="spnew_bf item" href="https://mkt.naver.com/p1/atrb?channel_id=naver_pcsearchmktbanner&amp;campaign_id=2311-clovax-001&amp;material=&amp;target=https%3A%2F%2Fclova-x.naver.com%2F" nocr="" onclick="return goOtherCR(this, 'a=bnr.link3&amp;r=3&amp;i=&amp;u=' + urlencode(this.href));" target="_blank"> <div class="ico_area"><img alt="" class="ico" height="36" src="https://csearch-phinf.pstatic.net/20231117_63/1700187410127JIVFp_PNG/760_31963112_marketing_banner_pc_icon_2_1700187409322.png" width="36"/></div> <div class="dsc_area"> <strong class="elss tit">CLOVA X와 함께 대화해 보세요</strong> <p class="elss dsc">대화형 AI 서비스 시작하기 </p> </div> </a> <a class="spnew_bf item" href="https://mkt.naver.com/p1/atrb?channel_id=naver_pcsearchmktbanner&amp;campaign_id=2401-mem-001&amp;target=https%3A%2F%2Fnid.naver.com%2Fmembership%2Fjoin%3Fdtm_source%3Dnaver_pcsearchmktbanner%26dtm_medium%3Dmktatrb_etc%26dtm_campaign%3D2401-mem-001" nocr="" onclick="return goOtherCR(this, 'a=bnr.link4&amp;r=4&amp;i=&amp;u=' + urlencode(this.href));" target="_blank"> <div class="ico_area"><img alt="" class="ico" height="36" src="https://csearch-phinf.pstatic.net/20240227_64/1709023555357lvTGc_PNG/760_31963112_marketing_banner_pc_icon_3_1709023555347.png" width="36"/></div> <div class="dsc_area"> <strong class="elss tit">이번 달은 꼭 적립 받고 사세요!</strong> <p class="elss dsc">최대 5% 적립 네이버플러스 멤버십</p> </div> </a> </div> </div> </section> <script> var nx_cr_right_area_info = [{"n": "rsk_top", "r": 1},{"n": "shX_ssC", "r": 2},{"n": "bnr", "r": 3}]; </script></div><div class="ly_dimmed"></div> </div> </div><div id="footer"> <div class="sub_pack_btm"> <a class="top" href="#" onclick="window.scrollTo(0,0); document.querySelect ...

# %%
temps = soup.find('div', 'temperature_text')
cast = soup.find('div', 'temperature_info')

print('->서울날씨 :', temps.get_text(), cast.get_text())
# Out:
# ->서울날씨 :  현재 온도6.0°   어제보다 2.1° 낮아요  맑음    체감 4.2°   습도 16%   북풍 2.3m/s
