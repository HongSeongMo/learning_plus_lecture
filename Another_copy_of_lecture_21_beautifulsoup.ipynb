# %% [markdown]
# <a href="https://colab.research.google.com/github/HongSeongMo/learning_plus_lecture/blob/main/Another_copy_of_lecture_21_beautifulsoup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# beatifulSoup 임포트
import datetime
from bs4 import BeautifulSoup
# !pip install urllib3
import urllib.request

now = datetime.datetime.now()
nowDate = now.strftime('%Y년 %m월 %d일 %H시 %M분')
nowDate
# Out:
# ...
# '2024년 03월 19일 04시 26분'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# 오늘의 날씨
webpage = urllib.request.urlopen('https://search.naver.com/search.naver?where=nexearch&sm=top_hty&fbm=0&ie=utf8&query=%EB%82%B4%EC%9D%BC+%EC%84%9C%EC%9A%B8+%EB%82%A0%EC%94%A8')
soup = BeautifulSoup(webpage, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
temps = soup.find('div', 'temperature_text')
cast = soup.find('div', 'temperature_info')

print('->서울날씨 :', temps.get_text(),'상황 :', cast.get_text())
# Out:
# ->서울날씨 :  현재 온도9.6°  상황 :  어제보다 3.2° 낮아요  흐림    체감 6.6°   습도 63%   남서풍 6.3m/s
